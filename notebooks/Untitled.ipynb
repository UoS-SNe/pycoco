# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

import sys
import os

import numpy as np
import pycoco as pcc

from astropy.table import Column, Table

# %%
snname = "SN2006aj"
sn = pcc.classes.SNClass(snname)

listfile = os.path.join(pcc.defaults._default_list_dir_path, snname + ".list")

sn.load_list(path=listfile)
# newpath = Column([os.path.join(pcc.defaults._default_data_dir_path, "spec_extended/") + path.split("/")[-1].replace(".txt", ".flat.txt") for path in sn.list["spec_path"]], name="spec_path")
newpath = Column(["/Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/"+ snname + "/" + path.split("/")[-1] for path in sn.list["spec_path"]], name="spec_path")

list_table = sn.list
sn.list = Table([newpath, list_table["snname"], list_table["mjd_obs"], list_table["z"]])

# %%
newpath
# Out:
# <Column name='spec_path' dtype='str107' length=19>
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-7.93.txt
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-6.97.txt
#                /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-6.0.txt
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-5.03.txt
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-4.06.txt
#                /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-3.1.txt
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-2.13.txt
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-1.16.txt
# ...

# %%
list_table = Table([newpath, list_table["snname"], list_table["mjd_obs"], list_table["z"]])
# Out:
# <Table length=19>
#                                                  spec_path                                                  ...
#                                                    str107                                                   ...
# ----------------------------------------------------------------------------------------------------------- ...
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-7.93.txt ...
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-6.97.txt ...
#                /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-6.0.txt ...
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-5.03.txt ...
#               /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/2006aj_-4.06.txt ...
# ...

# %%
list_table
# Out:
# <Table length=19>
#                     spec_path                      snname    mjd_obs       z
#                       str49                         str8     float64    float64
# ------------------------------------------------- -------- ------------ -------
#               data/spec/SN2006aj/2006aj_-7.93.txt SN2006aj     53786.27  0.0334
#               data/spec/SN2006aj/2006aj_-6.97.txt SN2006aj     53787.23  0.0334
#                data/spec/SN2006aj/2006aj_-6.0.txt SN2006aj      53788.2  0.0334
#               data/spec/SN2006aj/2006aj_-5.03.txt SN2006aj     53789.17  0.0334
#               data/spec/SN2006aj/2006aj_-4.06.txt SN2006aj     53790.14  0.0334
#                data/spec/SN2006aj/2006aj_-3.1.txt SN2006aj      53791.1  0.0334
#               data/spec/SN2006aj/2006aj_-2.13.txt SN2006aj     53792.07  0.0334
#               data/spec/SN2006aj/2006aj_-1.16.txt SN2006aj     53793.04  0.0334
# ...

# %%
specname ="iPTF13bvn_56471.020000.spec"

mjdobs  = np.float(specname.split("_")[-1].replace(".spec", ""))

# %%
mjdobs
# Out:
# 56471.02

# %%
sn

# %%
sn.list["z"][0]
# Out:
# 0.033399999999999999

# %%
listpath = "/Users/berto/data/CoreCollapse/Blue_extension/lists/" + snname+".list"

# %%
sn.load_list(listpath)

# %%
sn.list
# Out:
# <Table length=19>
#                                                spec_path                                                ...
#                                                  str103                                                 ...
# ------------------------------------------------------------------------------------------------------- ...
# /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53786.270000.spec ...
# /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53787.230000.spec ...
# /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53788.200000.spec ...
# /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53789.170000.spec ...
# /Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53790.140000.spec ...
# ...

# %%
sn.load_spec()
sn.plot_spec()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
listpath = "/Users/berto/data/CoreCollapse/Blue_extension/lists_final/" + snname+".list"

# %%
sn.load_spec()
sn.plot_spec()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
len(sn.spec)
# Out:
# 19

# %%
specpath = "/Users/berto/data/CoreCollapse/Blue_extension/spectra_blue_extended/SN2006aj/SN2006aj_53786.270000.spec"

# %%
S = pcc.classes.SpectrumClass()
S.load(specpath)

# %%
S.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
d = {}

# %%
d.keys()
# Out:
# dict_keys([])
