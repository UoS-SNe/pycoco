# %%
# %matplotlib notebook
from imp import reload  # Python 3.0 - 3.3
       
from matplotlib import pyplot as plt
from matplotlib import rc
# rc('text', usetex=True)

import os
import numpy as np
from astropy.table import Table

import pycocosn as pcc

# %%
extendedfilename = os.path.join(pcc.defaults._default_data_dir_path, "spec_blue_extended/SN1993J/SN1993J_49084.000000.spec")
S_extended = pcc.classes.SpectrumClass()
S_extended.load(filename=extendedfilename, abspath=True)
S_extended.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
filename = os.path.join(pcc.defaults._default_data_dir_path, "spec/SN1993J/1993J_-11.0.txt")
S = pcc.classes.SpectrumClass()
S.load(filename=filename, abspath=True)
S.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
snname = "SN1993J"
extended_dir = os.path.join(pcc.defaults._default_data_dir_path, "spec_blue_extended/"+snname)

# %%
spec_list = [i for i in os.listdir(extended_dir) if i.endswith(".spec")]

# %%
mjd_obs = [float(spec.replace(".spec", "").split("_")[-1]) for spec in spec_list]

# %%
mjd_obs
# Out:
# [49084.0,
#  49092.0,
#  49095.0,
#  49097.0,
#  49098.0,
#  49100.0,
#  49111.0,
#  49114.0,
#  49123.0,
#  49126.0,
#  49130.0,
#  49132.0,
#  49135.0,
#  49142.0]
