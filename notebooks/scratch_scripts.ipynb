# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
# P = pcc.load("/Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat", verbose = False)

# P.plot()

# P_new = pcc.PhotometryClass()
# P_new.load("/Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat", verbose = False)

# %%
sn = pcc.SNClass('SN2011dh')

sn.name
# Out:
# 'SN2011dh'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat

# %%
sn.phot.plot()

# %%
# sn.load_spec()

# %%
# pcc.read_list_file("/Users/berto/Dropbox/cc_templates/data/spec/SN2011dh.list")
sn.load_list("/Users/berto/Dropbox/cc_templates/data/spec/SN2011dh.list")

# %%
sn.load_spec()
# Out:
# Reading /Users/berto/Code/CoCo/data/spec/11eon_20110603_Keck1_v1.ascii
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-03-TNG-LRS-LRB-LRR.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-03-TNG-NICS-IJ-HK.dat
# Reading /Users/berto/Code/CoCo/data/spec/11eon_20110604_TNG_v2.ascii
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-04-ASIAGO-AFOSC-GR04.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-05-CA-CAFOS-B-200-R-200.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-05-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-06-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-08-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-08-WHT-ISIS-R300B-R158R.dat
# Reading /Users/berto/Code/CoCo/data/spec/11eon_20110609_Lick3-m_v1.ascii
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-10-WHT-ISIS-R300B-R158R.dat
# Reading /Users/berto/Code/CoCo/data/spec/11eon_20110612_WHT_v1.ascii
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-12-WHT-ISIS-R300B-R158R.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-17-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-20-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/11eon_20110629_P200_v1.ascii
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-30-CA-CAFOS-B-100-R-100.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-06-30-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-05-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-10-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-14-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-18-CA-CAFOS-B-200.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-19-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-22-NOT-ALFOSC-Grism_4-Grism_5.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-07-28-CA-CAFOS-B-100-R-100.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-10-CA-CAFOS-B-100-R-100.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-21-CA-CAFOS-B-200-R-200.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-28-ASIAGO-DU440-gt300.dat
# Reading /Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-30-WHT-ISIS-R300B-R158R.dat

# %%
sn.spec['11eon_20110603_Keck1_v1.ascii'].plot()
# Out:
# {'_meta': {'filename': '/Users/berto/Code/CoCo/data/spec/11eon_20110603_Keck1_v1.ascii'}, '_masked': False, '_copy_indices': True, '_column_class': <class 'astropy.table.column.Column'>, 'formatter': <astropy.table.pprint.TableFormatter object at 0x111269610>, '_init_indices': True, 'columns': <TableColumns names=('wavelength','flux','flux_err')>, 'primary_key': None}

# %%
sn.plot_spec(legend = False, verbose = True, add_mjd = True)
# Out:
# 0 100 11eon_20110603_Keck1_v1.ascii 3496 3496 3496
# 3496 Foo
# 1 75 SN2011dh-2011-06-03-TNG-LRS-LRB-LRR.dat 2219 2219 2219
# 2219 Foo
# 2 0 SN2011dh-2011-06-03-TNG-NICS-IJ-HK.dat 2306 2306 2306
# Not enough data to normalise
# 3 73 11eon_20110604_TNG_v2.ascii 1459 1459 1459
# 1459 Foo
# 4 41 SN2011dh-2011-06-04-ASIAGO-AFOSC-GR04.dat 533 533 533
# 533 Foo
# 5 46 SN2011dh-2011-06-05-CA-CAFOS-B-200-R-200.dat 1214 1214 1214
# 1214 Foo
# 6 67 SN2011dh-2011-06-05-NOT-ALFOSC-Grism_4-Grism_5.dat 1966 1966 1966
# 1966 Foo
# 7 66 SN2011dh-2011-06-06-NOT-ALFOSC-Grism_4-Grism_5.dat 1966 1966 1966
# 1966 Foo
# 8 67 SN2011dh-2011-06-08-NOT-ALFOSC-Grism_4-Grism_5.dat 1965 1965 1965
# 1965 Foo
# 9 233 SN2011dh-2011-06-08-WHT-ISIS-R300B-R158R.dat 7127 7127 7127
# 7127 Foo
# 10 197 11eon_20110609_Lick3-m_v1.ascii 6381 6381 6381
# 6381 Foo
# 11 232 SN2011dh-2011-06-10-WHT-ISIS-R300B-R158R.dat 6965 6965 6965
# 6965 Foo
# 12 110 11eon_20110612_WHT_v1.ascii 3554 3554 3554
# 3554 Foo
# 13 232 SN2011dh-2011-06-12-WHT-ISIS-R300B-R158R.dat 7128 7128 7128
# 7128 Foo
# 14 67 SN2011dh-2011-06-17-NOT-ALFOSC-Grism_4-Grism_5.dat 1966 1966 1966
# 1966 Foo
# 15 67 SN2011dh-2011-06-20-NOT-ALFOSC-Grism_4-Grism_5.dat 1967 1967 1967
# 1967 Foo
# 16 67 SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat 1937 1937 1937
# 1937 Foo
# 17 40 11eon_20110629_P200_v1.ascii 1291 1291 1291
# 1291 Foo
# 18 0 SN2011dh-2011-06-30-CA-CAFOS-B-100-R-100.dat 1919 1919 1919
# Not enough data to normalise
# 19 67 SN2011dh-2011-06-30-NOT-ALFOSC-Grism_4-Grism_5.dat 1902 1902 1902
# 1902 Foo
# 20 67 SN2011dh-2011-07-05-NOT-ALFOSC-Grism_4-Grism_5.dat 1851 1851 1851
# 1851 Foo
# 21 67 SN2011dh-2011-07-10-NOT-ALFOSC-Grism_4-Grism_5.dat 1932 1932 1932
# 1932 Foo
# 22 67 SN2011dh-2011-07-14-NOT-ALFOSC-Grism_4-Grism_5.dat 1936 1936 1936
# 1936 Foo
# 23 43 SN2011dh-2011-07-18-CA-CAFOS-B-200.dat 1085 1085 1085
# 1085 Foo
# 24 66 SN2011dh-2011-07-19-NOT-ALFOSC-Grism_4-Grism_5.dat 1938 1938 1938
# 1938 Foo
# 25 67 SN2011dh-2011-07-22-NOT-ALFOSC-Grism_4-Grism_5.dat 1932 1932 1932
# 1932 Foo
# 26 101 SN2011dh-2011-07-28-CA-CAFOS-B-100-R-100.dat 1346 1346 1346
# 1346 Foo
# 27 67 SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat 1896 1896 1896
# 1896 Foo
# 28 102 SN2011dh-2011-08-10-CA-CAFOS-B-100-R-100.dat 1321 1321 1321
# 1321 Foo
# 29 47 SN2011dh-2011-08-21-CA-CAFOS-B-200-R-200.dat 1203 1203 1203
# 1203 Foo
# 30 87 SN2011dh-2011-08-28-ASIAGO-DU440-gt300.dat 1306 1306 1306
# 1306 Foo
# 31 233 SN2011dh-2011-08-30-WHT-ISIS-R300B-R158R.dat 6965 6965 6965
# 6965 Foo
# -14.5659542837 1.52004109949

# %%
sn.spec['SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat'].plot()
# Out:
# {'_meta': {'filename': '/Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat'}, '_masked': False, '_copy_indices': True, '_column_class': <class 'astropy.table.column.Column'>, 'formatter': <astropy.table.pprint.TableFormatter object at 0x110045b50>, '_init_indices': True, 'columns': <TableColumns names=('wavelength','flux')>, 'primary_key': None}

# %%
np.nanmax(sn.spec['SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat'].data['wavelength'])
# Out:
# 9098.7008199904394

# %%
sn.spec['SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat'].flux
# Out:
# <Column name='flux' dtype='float64' unit='erg / (cm2 s)' length=1896>
# 1.09672681246e-15
# 9.33274070785e-16
# 1.13725822928e-15
# 1.26932703971e-15
# 1.34499942864e-15
# 1.35211125419e-15
# 1.25224042703e-15
# 1.10468236901e-15
# 1.00528958541e-15
# 8.92451163982e-16
# 9.77129533352e-16
# 1.15892441456e-15
#               ...
# 3.22019263306e-15
# 3.21731165209e-15
# 3.22112275109e-15
# 3.21492461414e-15
#  3.1879130326e-15
#  3.1680047969e-15
# 3.17886094375e-15
# 3.24177084136e-15
# 3.24014432727e-15
# 3.25403673974e-15
# 3.29240159104e-15
# 3.27007239855e-15
