# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import warnings

import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV

warnings.resetwarnings()

# %%
# sn = pcc.SNClass('SN2006aj')
sn = pcc.SNClass('SN2011dh')


sn.name
# Out:
# 'SN2011dh'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat

# %%
sn.phot.plot()

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2006aj.list")
sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh.list")

sn.list
# Out:
# <Table length=32>
#                               spec_path                               ...
#                                 str69                                 ...
# --------------------------------------------------------------------- ...
#                      data/spec/SN2011dh/11eon_20110603_Keck1_v1.ascii ...
#            data/spec/SN2011dh/SN2011dh-2011-06-03-TNG-LRS-LRB-LRR.dat ...
#             data/spec/SN2011dh/SN2011dh-2011-06-03-TNG-NICS-IJ-HK.dat ...
#                        data/spec/SN2011dh/11eon_20110604_TNG_v2.ascii ...
#          data/spec/SN2011dh/SN2011dh-2011-06-04-ASIAGO-AFOSC-GR04.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-06-05-CA-CAFOS-B-200-R-200.dat ...
# data/spec/SN2011dh/SN2011dh-2011-06-05-NOT-ALFOSC-Grism_4-Grism_5.dat ...
# data/spec/SN2011dh/SN2011dh-2011-06-06-NOT-ALFOSC-Grism_4-Grism_5.dat ...
# data/spec/SN2011dh/SN2011dh-2011-06-08-NOT-ALFOSC-Grism_4-Grism_5.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-06-08-WHT-ISIS-R300B-R158R.dat ...
#                                                                   ... ...
# data/spec/SN2011dh/SN2011dh-2011-07-14-NOT-ALFOSC-Grism_4-Grism_5.dat ...
#             data/spec/SN2011dh/SN2011dh-2011-07-18-CA-CAFOS-B-200.dat ...
# data/spec/SN2011dh/SN2011dh-2011-07-19-NOT-ALFOSC-Grism_4-Grism_5.dat ...
# data/spec/SN2011dh/SN2011dh-2011-07-22-NOT-ALFOSC-Grism_4-Grism_5.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-07-28-CA-CAFOS-B-100-R-100.dat ...
#         data/spec/SN2011dh/SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-08-10-CA-CAFOS-B-100-R-100.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-08-21-CA-CAFOS-B-200-R-200.dat ...
#         data/spec/SN2011dh/SN2011dh-2011-08-28-ASIAGO-DU440-gt300.dat ...
#       data/spec/SN2011dh/SN2011dh-2011-08-30-WHT-ISIS-R300B-R158R.dat ...

# %%
sn.load_spec()
# sn.spec['SN2006aj_vlt_2006_02_23_z0.dat.cal_galsub.txt'].plot()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
# recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2006aj.dat'))
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
sn.get_lcfit(recon_filename)

# %%
sn.lcfit.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
sn.phot.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
# sn.plot_lc(filters = ['B', 'V', 'R', 'I'])
sn.plot_lc()

# %%
# sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'], verbose = True)

# %%
warnings.resetwarnings()
