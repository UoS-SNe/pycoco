# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.pyc'>

# %%
sn = pcc.SNClass('SN2006aj')

sn.name
# Out:
# 'SN2006aj'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2006aj.dat

# %%
sn.phot.plot()

# %%
sn.load_list("/Users/berto/Dropbox/cc_templates/data/spec/SN2006aj.list")

# %%
sn.load_spec()

# %%
# sn.spec['11eon_20110603_Keck1_v1.ascii'].plot()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
# Out:
# {'_meta': {'filename': '/Users/berto/Code/CoCo/data/spec/SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat'}, '_masked': False, '_copy_indices': True, '_column_class': <class 'astropy.table.column.Column'>, 'formatter': <astropy.table.pprint.TableFormatter object at 0x10ff6bc10>, '_init_indices': True, 'columns': <TableColumns names=('wavelength','flux')>, 'primary_key': None}

# %%
# Out:
# 9098.7008199904394

# %%
# Out:
# <Column name='flux' dtype='float64' unit='erg / (cm2 s)' length=1896>
# 1.09672681246e-15
# 9.33274070785e-16
# 1.13725822928e-15
# 1.26932703971e-15
# 1.34499942864e-15
# 1.35211125419e-15
# 1.25224042703e-15
# 1.10468236901e-15
# 1.00528958541e-15
# 8.92451163982e-16
# 9.77129533352e-16
# 1.15892441456e-15
#               ...
# 3.22019263306e-15
# 3.21731165209e-15
# 3.22112275109e-15
# 3.21492461414e-15
#  3.1879130326e-15
#  3.1680047969e-15
# 3.17886094375e-15
# 3.24177084136e-15
# 3.24014432727e-15
# 3.25403673974e-15
# 3.29240159104e-15
# 3.27007239855e-15

# %%
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2006aj.dat'))
sn.get_fit(recon_filename)

# %%
sn.fit.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
sn.phot.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
sn.plot_lc(filters = ['B', 'V', 'R', 'I'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])
