# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import warnings

import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV

warnings.resetwarnings()

# %%
sn = pcc.SNClass('SN2006aj')

sn.name
# Out:
# 'SN2006aj'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2006aj.dat

# %%
sn.phot.plot()

# %%
sn.load_list("/Users/berto/Code/CoCo/lists/SN2006aj.list")
sn.list
# Out:
# <Table length=30>
#                             spec_path                             ...    z
#                               str65                               ... float64
# ----------------------------------------------------------------- ... -------
#                  data/spec/SN2006aj/SN2006aj_20060220_BTA.dat.txt ... 0.03351
# data/spec/SN2006aj/SN2006aj_lick_2006_02_22_z0.dat.cal_galsub.txt ... 0.03351
#                  data/spec/SN2006aj/SN2006aj_20060221_BTA.dat.txt ... 0.03351
#                     data/spec/SN2006aj/sn2006aj-20060222-fast.flm ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_02_21_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_02_23_z0.dat.cal_galsub.txt ... 0.03351
#                     data/spec/SN2006aj/sn2006aj-20060223-fast.flm ... 0.03351
#                      data/spec/SN2006aj/sn2006aj-20060223-mmt.flm ... 0.03351
#                     data/spec/SN2006aj/sn2006aj-20060224-fast.flm ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_02_25_z0.dat.cal_galsub.txt ... 0.03351
#                                                               ... ...     ...
#                      data/spec/SN2006aj/sn2006aj-20060302-mmt.flm ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_03_z0.dat.cal_galsub.txt ... 0.03351
#                      data/spec/SN2006aj/sn2006aj-20060303-mmt.flm ... 0.03351
#                     data/spec/SN2006aj/sn2006aj-20060303-fast.flm ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_04_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_05_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_06_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_08_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_09_z0.dat.cal_galsub.txt ... 0.03351
#  data/spec/SN2006aj/SN2006aj_vlt_2006_03_10_z0.dat.cal_galsub.txt ... 0.03351

# %%
sn.load_spec()
# sn.spec['SN2006aj_vlt_2006_02_23_z0.dat.cal_galsub.txt'].plot()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2006aj.dat'))
sn.get_fit(recon_filename)

# %%
sn.fit.data.keys()
# Out:
# ['B', 'V', 'R', 'I']

# %%
sn.phot.data.keys()
# Out:
# ['B', 'V', 'R', 'I']

# %%
sn.plot_lc(filters = ['B', 'V', 'R', 'I'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'], verbose = True)
# Out:
# Filter 'SDSS_g' not found
# Filter 'SDSS_r' not found
# Filter 'SDSS_i' not found
# Filter 'SDSS_z' not found
# /Users/berto/Code/verbose-enigma/pycoco/__init__.py:1401: UserWarning: Filter 'SDSS_g' not found
#
# /Users/berto/Code/verbose-enigma/pycoco/__init__.py:1401: UserWarning: Filter 'SDSS_r' not found
#
# /Users/berto/Code/verbose-enigma/pycoco/__init__.py:1401: UserWarning: Filter 'SDSS_i' not found
#
# /Users/berto/Code/verbose-enigma/pycoco/__init__.py:1401: UserWarning: Filter 'SDSS_z' not found

# %%
warnings.resetwarnings()
