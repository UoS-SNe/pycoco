# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2006aj')

sn.name
# Out:
# 'SN2011dh'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat

# %%
sn.phot.plot()

# %%
sn.plot_lc(lock_axis=True)

# %%
sn.plot_lc(['B'], multiplot = False)

# %%
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
sn.get_fit(recon_filename)

# %%
sn.plot_lc()

# %%
sn.plot_lc('B')

# %%
sn.phot.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
sn.plot_lc(filters = ['B', 'V', 'R', 'I'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
sn.load_list("/Users/berto/Dropbox/cc_templates/data/spec/SN2011dh.list")

# %%
sn.load_spec()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-77b9a282990b> in <module>()
# ----> 1 sn.plot_spec(legend = False, verbose = False, add_mjd = True)
#
# /Users/berto/Code/verbose-enigma/pycoco/__init__.py in plot_spec(self, xminorticks, legend, wmin, verbose, add_mjd, *args, **kwargs)
#    1528                         maxplotxdata = np.nanmax(np.append(maxplotxdata, np.nanmax(self.spec[spec_key].data['wavelength'])))
#    1529                         minplotxdata = np.nanmin(np.append(minplotxdata, np.nanmin(self.spec[spec_key].data['wavelength'])))
# -> 1530                     if add_mjd:
#    1531                         # ax1.plot([maxspecxdata, 11000],[1 - 0.5*j, 1 - 0.5*j], ls = '--', color = hex['batman'])
#    1532                         # ax1.plot([maxspecxdata, 11000],[yatmaxspecxdata, yatmaxspecxdata], ls = '--', color = hex['batman'])
#
# /Users/berto/anaconda2/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in text(self, x, y, s, fontdict, withdash, **kwargs)
#     626         if fontdict is not None:
#     627             t.update(fontdict)
# --> 628         t.update(kwargs)
#     629
#     630         t.set_clip_path(self.patch)
#
# /Users/berto/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in update(self, kwargs)
#     240         """
#     241         bbox = kwargs.pop('bbox', None)
# --> 242         super(Text, self).update(kwargs)
#     243         if bbox:
#     244             self.set_bbox(bbox)  # depends on font properties
#
# /Users/berto/anaconda2/lib/python2.7/site-packages/matplotlib/artist.pyc in update(self, props)
#     858                 if func is None or not six.callable(func):
#     859                     raise AttributeError('Unknown property %s' % k)
# --> 860                 func(v)
#     861             changed = True
#     862         self.eventson = store
#
# /Users/berto/anaconda2/lib/python2.7/site-packages/matplotlib/text.pyc in set_horizontalalignment(self, align)
#    1013         if align not in legal:
#    1014             raise ValueError('Horizontal alignment must be one of %s' %
# -> 1015                              str(legal))
#    1016         self._horizontalalignment = align
#    1017         self.stale = True
#
# ValueError: Horizontal alignment must be one of (u'center', u'right', u'left')

# %%
sn.spec[sn.spec.keys()[0]].plot()

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])
