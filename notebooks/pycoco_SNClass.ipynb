# %%
from __future__ import print_function ## Force python3-like printing
try:
    from importlib import reload
except:
    pass

# %matplotlib inline
# %matplotlib notebook

from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
# sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2006aj')
# sn = pcc.SNClass('SN2009jf')
sn = pcc.SNClass('SN2007uy')
sn.name
# Out:
# 'SN2007uy'

# %%
sn.load_phot( path = '/Users/berto/Code/verbose-enigma/testdata/lc/SN2007uy.dat', verbose = True)
# sn.load_phot( path = '/Users/berto/Code/verbose-enigma/testdata/lc/SN2009jf.dat', verbose = True)
# sn.load_phot( path = '/Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat', verbose = True)
# sn.load_phot( path = '/Users/berto/Code/verbose-enigma//testdata/lc/SN2006aj.dat', verbose = True)
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2007uy.dat

# %%
sn.phot.data_filters['BessellB'].__dict__
# Out:
# {'_cumulative_throughput': array([ 0.        ,  0.00312761,  0.01709758,  0.07620934,  0.1721226 ,
#          0.27408257,  0.37833611,  0.48029608,  0.57777314,  0.66670142,
#          0.74384904,  0.81057131,  0.86645121,  0.91065471,  0.94453711,
#          0.9690367 ,  0.98467473,  0.99457882,  0.99906172,  1.        ,  1.        ]),
#  '_cumulative_throughput_spline': <scipy.interpolate.interpolate.interp1d at 0x1206eedb8>,
#  '_filter_file_path': '/Users/berto/Code/CoCo/data/filters/BessellB.dat',
#  '_frequency_units': Unit("Hz"),
#  '_lower_edge': array(3784.9850746268658),
#  '_plot_colour': '#0000ff',
#  '_upper_edge': array(5203.284210526318),
#  '_wavelength_units': Unit("Angstrom"),
#  'filter_name': 'BessellB',
#  'lambda_effective': <Quantity 4354.410549343705 Angstrom>,
#  'throughput': array([ 0.   ,  0.03 ,  0.134,  0.567,  0.92 ,  0.978,  1.   ,  0.978,
#          0.935,  0.853,  0.74 ,  0.64 ,  0.536,  0.424,  0.325,  0.235,
#          0.15 ,  0.095,  0.043,  0.009,  0.   ]),
#  'wavelength': array([ 3600.,  3700.,  3800.,  3900.,  4000.,  4100.,  4200.,  4300.,
#          4400.,  4500.,  4600.,  4700.,  4800.,  4900.,  5000.,  5100.,
#          5200.,  5300.,  5400.,  5500.,  5600.]),
#  'wavelength_u': <Quantity [ 3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#              4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#              5400., 5500., 5600.] Angstrom>}

# %%
sn.phot.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2006aj.list")
# sn.load_list("/Users/berto/Code/CoCo/data/spec/SN2011dh.list")
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2009jf.list")
sn.load_list("/Users/berto/Code/CoCo/lists/SN2007uy.list")

sn.load_spec()
sn.plot_lc(lock_axis=True)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sn.plot_lc('BessellB', multiplot = False, verbose = False)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
# recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2009jf.dat'))
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2007uy.dat'))
sn.get_lcfit(recon_filename)

# %%
sn.plot_lc(xextent = 100)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sn.plot_lc('BessellB', verbose = True)
# Out:
# <img src="data:image/png;base64,..." width="800">
# 0 {'_masked': False, '_column_class': <class 'astropy.table.column.Column'>, 'columns': <TableColumns names=('MJD','flux','flux_err','filter')>, '_meta': OrderedDict(), 'formatter': <astropy.table.pprint.TableFormatter object at 0x11a56fa20>, '_copy_indices': True, '_init_indices': True, 'primary_key': None}
# 3490.62 3784.9850746268658
# 7366.46 5203.284210526318
# 2009jf_-7.64.txt
# False False
# 3491.2 3784.9850746268658
# 7368.49 5203.284210526318
# 2009jf_-3.67.txt
# False False
# 3490.73 3784.9850746268658
# 7369.48 5203.284210526318
# 2009jf_-0.69.txt
# False False
# 3490.68 3784.9850746268658
# 7370.89 5203.284210526318
# 2009jf_0.3.txt
# False False
# 3491.4 3784.9850746268658
# 9583.41 5203.284210526318
# 2009jf_2.28.txt
# False False
# 3490.68 3784.9850746268658
# 7369.43 5203.284210526318
# 2009jf_8.23.txt
# False False
# 3562.14 3784.9850746268658
# 7369.43 5203.284210526318
# 2009jf_24.11.txt
# False False
# 3490.16 3784.9850746268658
# 7367.45 5203.284210526318
# 2009jf_29.07.txt
# False False
# 3490.27 3784.9850746268658
# 7370.48 5203.284210526318
# 2009jf_33.04.txt
# False False
# xrange =  (55090.5, 55480.540000000001)
# yrange =  (0.0, 5.7782010000000005e-15)

# %%
sn.phot.data.keys()
# Out:
# odict_keys(['BessellB', 'SDSS_g', 'BessellV', 'SDSS_r', 'BessellR', 'SDSS_i', 'BessellI', 'SDSS_z'])

# %%
sn.plot_lc(filters = ['BessellB', 'BessellV', 'BessellR', 'BessellI'])
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'], xextent=100)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh_no_iz.list")
sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh.list")

# %%
sn.load_spec()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
sn.spec['11eon_20110603_Keck1_v1.ascii'].plot()

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
sn.plot_lc(lock_axis=True, filter_uncertainty=10)

# %%
print(len(sn.spec.keys()))

# %%
sn.spec['SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'].plot()

# %%
spec_key = 'SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'
filter_key = 'I'
too_red = sn.phot.data_filters[filter_key]._upper_edge > np.nanmax(sn.spec[spec_key].wavelength)
print(sn.phot.data_filters[filter_key]._upper_edge)
print(np.nanmax(sn.spec[spec_key].wavelength))
print(too_red)

# %%
sn.plot_filters(show_lims = True)

# %%
# %store -r x

# %%
x
