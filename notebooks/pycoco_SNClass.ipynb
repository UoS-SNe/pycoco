# %%
from __future__ import print_function ## Force python3-like printing
try:
    from importlib import reload
except:
    pass

# %matplotlib inline
# %matplotlib notebook

from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
# sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2006aj')
# sn = pcc.SNClass('SN2009jf')
sn = pcc.SNClass('SN2007uy')
sn.name
# Out:
# 'SN2007uy'

# %%
sn.load_phot( path = os.path.join(pcc._default_data_dir_path,"lc/SN2007uy.dat"), verbose = True)
# sn.load_phot( path = os.path.join(pcc._default_data_dir_path,"lc/SN2009jf.dat"), verbose = True)
# sn.load_phot( path = os.path.join(pcc._default_data_dir_path,"lc/SN2011dh.dat"), verbose = True)
# sn.load_phot( path = 'os.path.join(pcc._default_data_dir_path,"lc/SN2006aj.dat"), verbose = True)
# Out:
# /Users/berto/Code/CoCo/data/lc/SN2007uy.dat

# %%
sn.phot.data_filters["BessellB"].__dict__
# Out:
# {'_cumulative_throughput': <Column name='throughput' dtype='float64' length=21>
#               0.0
#  0.00312760633862
#   0.0170975813178
#   0.0762093411176
#    0.172122602168
#    0.274082568807
#    0.378336113428
#    0.480296080067
#    0.577773144287
#    0.666701417848
#    0.743849040867
#    0.810571309425
#    0.866451209341
#     0.91065471226
#    0.944537114262
#    0.969036697248
#    0.984674728941
#     0.99457881568
#    0.999061718098
#               1.0
#               1.0,
#  '_cumulative_throughput_spline': <scipy.interpolate.interpolate.interp1d at 0x10e8dcea8>,
#  '_filter_file_path': '/Users/berto/Code/CoCo/data/filters/BessellB.dat',
#  '_frequency_units': Unit("Hz"),
#  '_lower_edge': array(3784.9850746268658),
#  '_plot_colour': '#0000ff',
#  '_upper_edge': array(5203.284210526318),
#  '_wavelength_units': Unit("Angstrom"),
#  'data': <Table length=21>
#  wavelength throughput
#   float64    float64
#  ---------- ----------
#      3600.0        0.0
#      3700.0       0.03
#      3800.0      0.134
#      3900.0      0.567
#      4000.0       0.92
#      4100.0      0.978
#      4200.0        1.0
#      4300.0      0.978
#      4400.0      0.935
#      4500.0      0.853
#      4600.0       0.74
#      4700.0       0.64
#      4800.0      0.536
#      4900.0      0.424
#      5000.0      0.325
#      5100.0      0.235
#      5200.0       0.15
#      5300.0      0.095
#      5400.0      0.043
#      5500.0      0.009
#      5600.0        0.0,
#  'filter_name': 'BessellB',
#  'lambda_effective': <Quantity 4354.410549343705 Angstrom>,
#  'throughput': <Column name='throughput' dtype='float64' length=21>
#    0.0
#   0.03
#  0.134
#  0.567
#   0.92
#  0.978
#    1.0
#  0.978
#  0.935
#  0.853
#   0.74
#   0.64
#  0.536
#  0.424
#  0.325
#  0.235
#   0.15
#  0.095
#  0.043
#  0.009
#    0.0,
#  'wavelength': <Quantity [ 3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#              4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#              5400., 5500., 5600.] Angstrom>,
#  'wavelength_u': <Quantity [ 3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#              4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#              5400., 5500., 5600.] Angstrom>}

# %%
sn.phot.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Listfiles
# ---
#
# listfiles

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2006aj.list")
# sn.load_list("/Users/berto/Code/CoCo/data/spec/SN2011dh.list")
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2009jf.list")
sn.load_list(os.path.join(pcc._default_coco_dir_path,"lists/SN2007uy.list"))

# %%
sn.list
# Out:
# <Table length=10>
#              spec_path                snname  mjd_obs     z     phase
#                str36                   str8   float64  float64 float64
# ------------------------------------ -------- -------- ------- -------
# data/spec/SN2007uy/2007uy_-13.01.txt SN2007uy 54468.09   0.007  -13.01
# data/spec/SN2007uy/2007uy_-11.02.txt SN2007uy 54470.08   0.007  -11.02
#  data/spec/SN2007uy/2007uy_-6.06.txt SN2007uy 54475.04   0.007   -6.06
#  data/spec/SN2007uy/2007uy_-5.06.txt SN2007uy 54476.04   0.007   -5.06
#  data/spec/SN2007uy/2007uy_-3.08.txt SN2007uy 54478.02   0.007   -3.08
#  data/spec/SN2007uy/2007uy_12.81.txt SN2007uy 54493.91   0.007   12.81
#  data/spec/SN2007uy/2007uy_45.58.txt SN2007uy 54526.68   0.007   45.58
#  data/spec/SN2007uy/2007uy_54.52.txt SN2007uy 54535.62   0.007   54.52
#  data/spec/SN2007uy/2007uy_75.37.txt SN2007uy 54556.47   0.007   75.37
# data/spec/SN2007uy/2007uy_140.91.txt SN2007uy 54622.01   0.007  140.91

# %%
checklist = pcc.utils.check_all_lists(pcc._default_list_dir_path, verbose=False)
# Out:
# iPTF13bvn.list  passed
# SN1993J.list  passed
# SN1994I.list  passed
# SN1996cb.list  passed
# SN1998bw.list  passed
# SN1999dn.list  passed
# SN2002ap.list  passed
# SN2003jd.list  passed
# SN2004aw.list  passed
# SN2005bf.list  passed
# SN2005hg.list  passed
# SN2006aj.list  passed
# SN2007C.list  passed
# SN2007gr.list  passed
# SN2007uy.list  passed
# SN2007Y.list  passed
# SN2008ax.list  passed
# SN2008bo.list  passed
# SN2008D.list  passed
# SN2009bb.list  passed
# SN2009er.list  passed
# SN2009iz.list  passed
# SN2009jf.list  passed
# SN2010al.list  passed
# SN2011bm.list  passed
# SN2011dh.list  passed
# SN2011ei.list  passed
# SN2011fu.list  passed
# SN2012ap.list  passed
# SN2013ge.list  passed

# %%
# Out:
# False

# %%
sn.load_spec()
sn.plot_lc(lock_axis=True)

# %%
sn.plot_lc('BessellB', multiplot = False, verbose = False)

# %%
# recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
# recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2009jf.dat'))
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2007uy.dat'))
sn.get_lcfit(recon_filename)

# %%
sn.plot_lc(xextent = 100)

# %%
sn.plot_lc('BessellB', verbose = True)

# %%
sn.phot.data.keys()

# %%
sn.plot_lc(filters = ['BessellB', 'BessellV', 'BessellR', 'BessellI'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'], xextent=100)

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh_no_iz.list")
sn.load_list(os.path.join(pcc._default_coco_dir_path, "lists/SN2011dh.list"))

# %%
sn.load_spec()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
sn.spec['11eon_20110603_Keck1_v1.ascii'].plot()

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
sn.plot_lc(lock_axis=True, filter_uncertainty=10)

# %%
print(len(sn.spec.keys()))

# %%
sn.spec['SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'].plot()

# %%
spec_key = 'SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'
filter_key = 'I'
too_red = sn.phot.data_filters[filter_key]._upper_edge > np.nanmax(sn.spec[spec_key].wavelength)
print(sn.phot.data_filters[filter_key]._upper_edge)
print(np.nanmax(sn.spec[spec_key].wavelength))
print(too_red)

# %%
sn.plot_filters(show_lims = True)

# %%
# %store -r x

# %%
x
