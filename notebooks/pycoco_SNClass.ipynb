# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2006aj')

sn.name
# Out:
# 'SN2011dh'

# %%
sn.load_phot()
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat

# %%
sn.phot.plot()

# %%
sn.plot_lc()

# %%
sn.plot_lc(['B'])

# %%
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
sn.get_fit(recon_filename)

# %%
sn.plot_lc()

# %%
sn.plot_lc('B')

# %%
sn.phot.data.keys()
# Out:
# ['B', 'SDSS_g', 'V', 'SDSS_r', 'R', 'SDSS_i', 'I', 'SDSS_z']

# %%
sn.plot_lc(filters = ['B', 'V', 'R', 'I'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
sn.load_list("/Users/berto/Dropbox/cc_templates/data/spec/SN2011dh.list")

# %%
sn.load_spec()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
sn.spec[sn.spec.keys()[0]].plot()
# Out:
# {'_meta': {'filename': '/Users/berto/Code/CoCo/data/spec/11eon_20110603_Keck1_v1.ascii'}, '_masked': False, '_copy_indices': True, '_column_class': <class 'astropy.table.column.Column'>, 'formatter': <astropy.table.pprint.TableFormatter object at 0x111b57810>, '_init_indices': True, 'columns': <TableColumns names=('wavelength','flux','flux_err')>, 'primary_key': None}
