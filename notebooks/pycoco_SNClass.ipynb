# %%
from __future__ import print_function ## Force python3-like printing

# %matplotlib inline
from matplotlib import pyplot as plt

import os
import numpy as np
from astropy.table import Table

import pycoco as pcc

reload(pcc) ## FOR DEV
# Out:
# <module 'pycoco' from '/Users/berto/Code/verbose-enigma/pycoco/__init__.py'>

# %%
# sn = pcc.SNClass('SN2011dh')
sn = pcc.SNClass('SN2011dh')
# sn = pcc.SNClass('SN2006aj')

sn.name
# Out:
# 'SN2011dh'

# %%
sn.load_phot( path = '/Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat', verbose = True)
# sn.load_phot( path = '/Users/berto/Code/verbose-enigma//testdata/lc/SN2006aj.dat', verbose = True)
# Out:
# /Users/berto/Code/verbose-enigma/testdata/lc/SN2011dh.dat

# %%
sn.phot.data_filters['BessellB'].__dict__
# Out:
# {'_cumulative_throughput': array([ 0.        ,  0.00312761,  0.01709758,  0.07620934,  0.1721226 ,
#          0.27408257,  0.37833611,  0.48029608,  0.57777314,  0.66670142,
#          0.74384904,  0.81057131,  0.86645121,  0.91065471,  0.94453711,
#          0.9690367 ,  0.98467473,  0.99457882,  0.99906172,  1.        ,  1.        ]),
#  '_cumulative_throughput_spline': <scipy.interpolate.interpolate.interp1d at 0x1108df368>,
#  '_filter_file_path': '/Users/berto/Code/CoCo/data/filters/BessellB.dat',
#  '_frequency_units': Unit("Hz"),
#  '_lower_edge': array(3784.9850746268658),
#  '_plot_colour': '#0000ff',
#  '_upper_edge': array(5203.284210526318),
#  '_wavelength_units': Unit("Angstrom"),
#  'filter_name': 'BessellB',
#  'lambda_effective': <Quantity 4354.410549343705 Angstrom>,
#  'throughput': array([ 0.   ,  0.03 ,  0.134,  0.567,  0.92 ,  0.978,  1.   ,  0.978,
#          0.935,  0.853,  0.74 ,  0.64 ,  0.536,  0.424,  0.325,  0.235,
#          0.15 ,  0.095,  0.043,  0.009,  0.   ]),
#  'wavelength': array([ 3600.,  3700.,  3800.,  3900.,  4000.,  4100.,  4200.,  4300.,
#          4400.,  4500.,  4600.,  4700.,  4800.,  4900.,  5000.,  5100.,
#          5200.,  5300.,  5400.,  5500.,  5600.]),
#  'wavelength_u': <Quantity [ 3600., 3700., 3800., 3900., 4000., 4100., 4200., 4300., 4400.,
#              4500., 4600., 4700., 4800., 4900., 5000., 5100., 5200., 5300.,
#              5400., 5500., 5600.] Angstrom>}

# %%
sn.phot.plot()

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2006aj.list")
sn.load_list("/Users/berto/Code/CoCo/data/spec/SN2011dh.list")

sn.load_spec()

sn.plot_lc(lock_axis=True)

# %%
sn.plot_lc('BessellB', multiplot = False, verbose = False)
# Out:
# True False
# 3490.18188477 3784.98507463
# 9208.00976563 5203.28421053
# SN2011dh-2011-06-30-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3642.61108398 3784.98507463
# 9208.43554688 5203.28421053
# SN2011dh-2011-07-05-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3491.01076849 3784.98507463
# 9209.36523438 5203.28421053
# SN2011dh-2011-07-10-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3492.81717602 3784.98507463
# 9207.11035156 5203.28421053
# SN2011dh-2011-07-14-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3641.29822254 3784.98507463
# 8705.87735653 5203.28421053
# SN2011dh-2011-07-18-CA-CAFOS-B-200.dat
# False False
# 3492.34879288 3784.98507463
# 9207.11914063 5203.28421053
# SN2011dh-2011-07-19-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3491.058329 3784.98507463
# 9207.78125 5203.28421053
# SN2011dh-2011-07-22-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3640.81395912 3784.98507463
# 6308.8019495 5203.28421053
# SN2011dh-2011-07-28-CA-CAFOS-B-100-R-100.dat
# False False
# 3490.18526935 3784.98507463
# 9108.70081999 5203.28421053
# SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat
# False False
# 3691.19223046 3784.98507463
# 6309.71343446 5203.28421053
# SN2011dh-2011-08-10-CA-CAFOS-B-100-R-100.dat
# False False
# 3541.38539124 3784.98507463
# 8708.48874664 5203.28421053
# SN2011dh-2011-08-21-CA-CAFOS-B-200-R-200.dat
# False False
# 4491.67990892 3784.98507463
# 7509.28855699 5203.28421053
# SN2011dh-2011-08-28-ASIAGO-DU440-gt300.dat
# True False
# 3490.3594123 3784.98507463
# 9209.69140625 5203.28421053
# SN2011dh-2011-08-30-WHT-ISIS-R300B-R158R.dat
# False False

# %%
recon_filename = os.path.abspath(os.path.join('/Users/berto/Code/CoCo/recon/', 'SN2011dh.dat'))
sn.get_lcfit(recon_filename)
# Out:
# BessellB
# SDSS_g
# BessellV
# SDSS_r
# BessellR
# SDSS_i
# BessellI
# SDSS_z

# %%
sn.plot_lc()

# %%
sn.plot_lc('BessellB', verbose = True)
# Out:
# 0 {'_meta': OrderedDict(), '_masked': False, '_copy_indices': True, '_column_class': <class 'astropy.table.column.Column'>, 'formatter': <astropy.table.pprint.TableFormatter object at 0x110c76750>, '_init_indices': True, 'columns': <TableColumns names=('MJD','flux','flux_err','filter')>, 'primary_key': None}
# 3492.0 3784.98507463
# 10210.0 5203.28421053
# 11eon_20110603_Keck1_v1.ascii
# False False
# 3491.0719747 3784.98507463
# 9208.99511719 5203.28421053
# SN2011dh-2011-06-03-TNG-LRS-LRB-LRR.dat
# SN2011dh-2011-07-10-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3492.81717602 3784.98507463
# 9207.11035156 5203.28421053
# SN2011dh-2011-07-14-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3641.29822254 3784.98507463
# 8705.87735653 5203.28421053
# SN2011dh-2011-07-18-CA-CAFOS-B-200.dat
# False False
# 3492.34879288 3784.98507463
# 9207.11914063 5203.28421053
# SN2011dh-2011-07-19-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3491.058329 3784.98507463
# 9207.78125 5203.28421053
# SN2011dh-2011-07-22-NOT-ALFOSC-Grism_4-Grism_5.dat
# False False
# 3640.81395912 3784.98507463
# 6308.8019495 5203.28421053
# SN2011dh-2011-07-28-CA-CAFOS-B-100-R-100.dat
# False False
# 3490.18526935 3784.98507463
# 9108.70081999 5203.28421053
# SN2011dh-2011-08-06-NOT-ALFOSC-Grism_4.dat
# False False
# 3691.19223046 3784.98507463
# 6309.71343446 5203.28421053
# SN2011dh-2011-08-10-CA-CAFOS-B-100-R-100.dat
# False False
# 3541.38539124 3784.98507463
# 8708.48874664 5203.28421053
# SN2011dh-2011-08-21-CA-CAFOS-B-200-R-200.dat
# False False
# 4491.67990892 3784.98507463
# 7509.28855699 5203.28421053
# SN2011dh-2011-08-28-ASIAGO-DU440-gt300.dat
# True False
# 3490.3594123 3784.98507463
# 9209.69140625 5203.28421053
# SN2011dh-2011-08-30-WHT-ISIS-R300B-R158R.dat
# False False

# %%
sn.phot.data.keys()

# %%
sn.plot_lc(filters = ['BessellB', 'BessellV', 'BessellR', 'BessellI'])

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
# sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh_no_iz.list")
sn.load_list("/Users/berto/Code/CoCo/lists/SN2011dh.list")

# %%
sn.load_spec()

# %%
sn.plot_spec(legend = False, verbose = False, add_mjd = True)

# %%
sn.spec['11eon_20110603_Keck1_v1.ascii'].plot()

# %%
sn.plot_lc(filters = ['SDSS_g', 'SDSS_r', 'SDSS_i', 'SDSS_z'])

# %%
sn.plot_lc(lock_axis=True, filter_uncertainty=10)

# %%
print(len(sn.spec.keys()))

# %%
sn.spec['SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'].plot()

# %%
spec_key = 'SN2011dh-2011-06-25-NOT-ALFOSC-Grism_4-Grism_5.dat'
filter_key = 'I'
too_red = sn.phot.data_filters[filter_key]._upper_edge > np.nanmax(sn.spec[spec_key].wavelength)
print(sn.phot.data_filters[filter_key]._upper_edge)
print(np.nanmax(sn.spec[spec_key].wavelength))
print(too_red)

# %%
sn.plot_filters(show_lims = True)
