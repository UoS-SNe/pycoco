# %%
# %matplotlib inline
# %matplotlib notebook

try:
    from importlib import reload
except:
    pass

import os
import sys
import numpy as np
from astropy.table import Table

import pycoco as pcc

# %%
data_path = "/Users/berto/data/CoreCollapse/crangus_DES/DES16C3cv_orig.dat"
p = pcc.PhotometryClass()
p.load(data_path)
p.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
T = p._phot_format_for_save()

# %%
T = T[T.argsort()]

# %%
pt = T[np.where(T["MJD"] >= 57600)]

# %%
pt
# Out:
# <Table length=116>
#    MJD             flux                 flux_err        filter
#     d     erg / (Angstrom cm2 s) erg / (Angstrom cm2 s)
#  float64         float64                float64          str5
# --------- ---------------------- ---------------------- ------
# 57615.374      6.07745208089e-19         2.02873529e-19  DES_i
# 57615.399      4.97199558508e-19      8.54863400046e-20  DES_r
# 57616.312      4.69443657569e-19      4.68654198106e-20  DES_z
# 57623.272      3.58703065686e-19      5.80319224127e-19  DES_g
# 57623.283      6.02224961483e-19      6.23109001233e-20  DES_i
# 57623.312      7.28268601596e-19      1.05513200495e-19  DES_r
# 57623.331       4.9800655979e-19      3.78526399707e-20  DES_z
# 57624.275      3.03448217455e-19      3.22460133089e-19  DES_g
# 57627.415      5.66980568333e-19      8.41922481526e-20  DES_r
#       ...                    ...                    ...    ...
# 57779.091       1.5770219067e-18      4.82726807601e-20  DES_i
# ...

# %%
p_short = pcc.PhotometryClass()
p_short.load_table(pt)

# %%
p_short.plot()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
p_short.save(filename="DES16C3cv.dat", path = "/Users/berto/data/CoreCollapse/crangus_DES")
# Out:
# has data
# /Users/berto/data/CoreCollapse/crangus_DES/DES16C3cv.dat
# Writing /Users/berto/data/CoreCollapse/crangus_DES/DES16C3cv.dat

# %%
sn = pcc.SNClass("DES16C3cv")
sn.load_phot(path="/Users/berto/data/CoreCollapse/crangus_DES/DES16C3cv.dat")
sn.get_lcfit(os.path.join(pcc._default_coco_dir_path, "recon/" + sn.name + ".dat"))

# %%
sn.plot_lc(multiplot=False)
# Out:
# <img src="data:image/png;base64,..." width="800">
