# %% [markdown]
# ## Adding SNe to CoCo
# ___
#
# This notebook will go through adding a SN to the CoCo template framework.

# %%
# %matplotlib inline
# %matplotlib notebook

try:
    reload  # Python 2.7
except NameError:
    try:
        from importlib import reload  # Python 3.4+
    except ImportError:
        from imp import reload  # Python 3.0 - 3.3
        
from matplotlib import pyplot as plt
from matplotlib import rc
rc('text', usetex=True)

import os
import numpy as np
from astropy.table import Table, Column
from collections import OrderedDict

import pycoco as pcc

# %% [markdown]
# ## Download SN
# ---
# The example that I will go through is probably the simplest one - from a JSON that I have downloaded from http://sne.space contaning the information for SN2015U.

# %%
import json

# %%
snname = "SN2006aj"
path = "/Users/berto/data/CoreCollapse/SNe/SN2006aj.json"

sndict = json.load(open(path, 'r'))[snname]

# %%
sndict.keys()
# Out:
# dict_keys(['schema', 'name', 'sources', 'alias', 'claimedtype', 'comovingdist', 'dec', 'discoverdate', 'discoverer', 'ebv', 'host', 'hostdec', 'hostoffsetang', 'hostoffsetdist', 'hostra', 'lumdist', 'maxabsmag', 'maxappmag', 'maxband', 'maxdate', 'maxvisualabsmag', 'maxvisualappmag', 'maxvisualband', 'maxvisualdate', 'ra', 'redshift', 'velocity', 'photometry', 'spectra'])

# %%
sndict["redshift"][0]["value"]
# Out:
# '0.033023'

# %%
len(sndict["spectra"])
# Out:
# 45

# %%
S1 = sndict["spectra"][0]

# %%
S1.keys()
# Out:
# dict_keys(['time', 'filename', 'instrument', 'observer', 'redshift', 'reducer', 'reduction', 'u_fluxes', 'u_time', 'u_wavelengths', 'data', 'source'])

# %%
w = np.array(S1["data"], dtype=np.float64).T[0]
f = np.array(S1["data"], dtype=np.float64).T[1]

# %%
f
# Out:
# array([  4.39589000e-16,   4.19307000e-16,   4.83004000e-16, ...,
#          1.18609000e-16,   1.12715000e-16,   1.07753000e-16])

# %%
from astropy.table import Table, Column, Row
import astropy.units as u

# %%
wavelength = Column(w, name = ("wavelength"), unit=u.Angstrom)
flux = Column(f, name = ("flux"), unit=u.cgs.erg / u.si.s / u.si.cm ** 2 / u.angstrom)

# %%
Table([wavelength, flux])
# Out:
# <Table length=1846>
# wavelength          flux
#  Angstrom  erg / (Angstrom cm2 s)
#  float64          float64
# ---------- ----------------------
# 3658.54734            4.39589e-16
# 3660.63714            4.19307e-16
# 3662.72695            4.83004e-16
# 3664.82688            1.88873e-16
# 3666.91668            3.10752e-16
# 3669.00649              7.741e-16
#  3671.0964            4.81727e-16
#  3673.1862            2.84237e-16
# 3675.27601            3.49466e-16
#        ...                    ...
# 7496.11126            1.13298e-16
# 7498.20106            1.16063e-16
# 7500.29097            1.11652e-16
# 7502.38078            1.13903e-16
# 7504.47058              1.148e-16
# 7506.56049             1.1918e-16
#  7508.6503            1.19524e-16
#  7510.7402            1.18609e-16
# 7512.83001            1.12715e-16
# 7514.91982            1.07753e-16

# %%
spec_dict_list = sndict["spectra"]
for i, s in enumerate(spec_dict_list):
    print(i, s["time"], s["filename"])
# Out:
# 0 53786.0 SN2006aj_20060220_BTA.dat
#   ['6023.703995', '1.252089E-16'],
#   ['6026.308574', '1.218670E-16'],
#   ['6028.913153', '1.210255E-16'],
#   ['6031.517732', '1.264217E-16'],
#   ['6034.122311', '1.244563E-16'],
#   ['6036.72689', '1.240048E-16'],
#   ['6039.331469', '1.276224E-16'],
#   ['6041.936048', '1.250852E-16'],
#   ['6044.540627', '1.254013E-16'],
#   ['6047.145206', '1.271772E-16'],
#   ['6049.749785', '1.231525E-16'],
#   ['6052.354364', '1.239900E-16'],
#   ['6054.958943', '1.220444E-16'],
#   ['6057.563522', '1.219916E-16'],
#   ['6060.168102', '1.251125E-16'],
#   ['6062.772681', '1.252626E-16'],
#   ['6065.37726', '1.250374E-16'],
#   ['6067.981839', '1.278272E-16'],
#   ['6070.586418', '1.282514E-16'],
#   ['6073.190997', '1.252551E-16'],
#   ['6075.795576', '1.237615E-16'],
#   ['6078.400155', '1.220905E-16'],
#   ['6081.004734', '1.225901E-16'],
#   ['6083.609313', '1.200212E-16'],
#   ['6086.213892', '1.159392E-16'],
#   ['6088.818471', '1.204029E-16'],
#   ['6091.42305', '1.247080E-16'],
#   ['6094.027629', '1.222005E-16'],
#   ['6096.632208', '1.203947E-16'],
#   ['6099.236788', '1.202272E-16'],
#   ['6101.841367', '1.224943E-16'],
#   ['6104.445946', '1.190681E-16'],
#   ['6107.050525', '1.197031E-16'],
#   ['6109.655104', '1.185470E-16'],
#   ['6112.259683', '1.180653E-16'],
#   ['6114.864262', '1.170896E-16'],
#   ['6117.468841', '1.209503E-16'],
#   ['6120.07342', '1.165791E-16'],
#   ['6122.677999', '1.156761E-16'],
#   ['6125.282578', '1.173198E-16'],
#   ['6127.887157', '1.175480E-16'],
#   ['6130.491736', '1.120701E-16'],
#   ['6133.096315', '1.138030E-16'],
#   ['6135.700895', '1.140087E-16'],
#   ['6138.305474', '1.144515E-16'],
#   ['6140.910053', '1.130368E-16'],
#   ...],
#  'filename': 'SN2006aj_vlt_2006_03_10_z0.dat',
#  'instrument': 'VLT-UT2 - FORS1-UT2',
#  'observer': 'Unknown',
#  'redshift': '0.033023',
#  'reducer': 'Unknown',
#  'reduction': 'final',
#  'source': '14,20',
#  'time': '53804.0',
#  'u_fluxes': 'erg/s/cm^2/Angstrom',
#  'u_time': 'MJD',
#  'u_wavelengths': 'Angstrom'}

# %%
print(len(spec_dict_list))
# Out:
# 45

# %%
spec_dict_list[23]["time"]
# Out:
# '53794.0'

# %%
# to_combine = ["SN10as_100325_VLT_XS_", 
#               "SN10as_100326_VLT_XS_", 
#               "SN10as_100328_VLT_XS_", 
#               "SN10as_100329_VLT_XS_"]

# to_combine_phases = [55280.0,
#                      55281.0,
#                      55283.0,
#                      55284.0]

# spec_filenames = [spec["filename"] for spec in sndict["spectra"]]
# # spec_filenames = [spec["filename"][:-7] for spec in sndict["spectra"]]
# mask = np.ones(len(spec_dict_list), dtype=bool)

# combined = np.array([])

# for prefix in to_combine:
#     matches = [f for f in spec_filenames if prefix in f]
#     print(matches)
    
#     spec_dir = "/Users/berto/data/CoreCollapse/data/spectra/SN2010as/"
    
#     tables = []
#     out_dict = OrderedDict()
#     for file in matches:
#         w = np.where(np.array(spec_filenames) == file)[0]
        
#         wavl = np.array(spec_dict_list[w]["data"], dtype=np.float64).T[0]
#         flux = np.array(spec_dict_list[w]["data"], dtype=np.float64).T[1]
        
#         wavelength = Column(wavl, name = ("wavelength"), unit=u.Angstrom)
#         flux = Column(flux, name = ("flux"), unit=u.cgs.erg / u.si.cm ** 2 / u.si.s / u.angstrom)
     
#         tables.append(Table([wavelength, flux]))
        
#         for i in w:
#             print(i, spec_dict_list[i]["filename"])
#             mask[i] = False
# #             spec_dict_list.pop(i)
            
#     tables = np.array(tables)[np.argsort([i["wavelength"][0] for i in tables])]
    
#     S1 = pcc.SpectrumClass()
#     S2 = pcc.SpectrumClass()
#     S3 = pcc.SpectrumClass()
    
#     S1.load_table(tables[0], path="")
#     S2.load_table(tables[1], path="")
#     S3.load_table(tables[2], path="")
    
#     sr=pcc.functions.combine_spectra(S2, S3, 9975, 10150, scale=True)
#     spec = pcc.functions.combine_spectra(S1,sr, 5502.5, 5525)
    
#     out_spec = pcc.SpectrumClass()
#     out_spec.load_table(spec.data, path="", trim_wavelength=True, wmin=0, wmax=15000)
    
#     filename = prefix+"combined.dat"
    
#     out_dict["filename"] = os.path.join(spec_dir, filename)
#     out_dict["time"] = np.float64(spec_dict_list[w]["time"])
#     out_dict["redshift"] = spec_dict_list[w]["redshift"]
#     out_dict["snname"] = snname
    
#     combined = np.append(combined, out_dict)
    
# #     spec.plot()
# #     spec.save(filename, path=spec_dir, format="ascii.commented_header", verbose=True)
#     out_spec.plot()
#     out_spec.save(filename, path=spec_dir, format="ascii.commented_header", verbose=True)

# %%
out_dict = OrderedDict()

# %%
uncombined=np.array([])
spec_filenames = [spec["filename"] for spec in sndict["spectra"]]
# print(spec_filenames)
spec_dir = "/Users/berto/data/CoreCollapse/data/spectra/SN2006aj/"

# %%
for spec_file in np.array(spec_filenames):
# for spec_file in np.array(spec_filenames)[mask]:
    print(spec_file)
    
    w = np.where(np.array(spec_filenames) == spec_file)[0][0]
    print(w)
    
    wavl = np.array(spec_dict_list[w]["data"], dtype=np.float64).T[0]
    flux = np.array(spec_dict_list[w]["data"], dtype=np.float64).T[1]

    wavelength = Column(wavl, name = ("wavelength"), unit=u.Angstrom)
#     wavelength = Column(wavl*(1+np.float64(sndict["redshift"][0]["value"])), name = ("wavelength"), unit=u.Angstrom)

    flux = Column(flux, name = ("flux"), unit=u.cgs.erg / u.si.cm ** 2 / u.si.s / u.angstrom)

    spec_table = Table([wavelength, flux])

    s = pcc.SpectrumClass()

    s.load_table(spec_table, path="", wmin=1 * u.angstrom, wmax=100000 * u.angstrom)
    print(os.path.join(spec_dir, spec_file))
#     s.save(spec_file, path=spec_dir, squash = True)
    out_dict = OrderedDict()
    out_dict["filename"] = os.path.join(spec_dir, spec_file)
    out_dict["time"] = np.float64(spec_dict_list[w]["time"])
    out_dict["redshift"] = np.float64(sndict["redshift"][0]["value"])
    print("redshift ", out_dict["redshift"])
    out_dict["snname"] = snname
    print(spec_dict_list[w]["time"])
    uncombined = np.append(uncombined, out_dict)
    
    s.plot()
# Out:
# SN2006aj_20060220_BTA.dat
# 0
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj
Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_03_z0.dat
# redshift  0.033023
# 53797.0
# sn2006aj-20060303-mmt.flm
# 31
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060303-mmt.flm
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060303-mmt.flm
# redshift  0.033023
# 53797.0
# sn2006aj-20060303.flm
# 32
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060303.flm
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060303.flm
# redshift  0.033023
# 53797.0
# SN2006aj_vlt_2006_03_04_z0.dat
# 33
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_04_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_04_z0.dat
# redshift  0.033023
# 53798.0
# SN2006aj_vlt_2006_03_05_z0.dat
# 34
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_05_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_05_z0.dat
# redshift  0.033023
# 53799.0
# SN2006aj_vlt_2006_03_06_z0.dat
# 35
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_06_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_06_z0.dat
# redshift  0.033023
# 53800.0
# SN2006aj_vlt_2006_03_08_z0.dat
# 36
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_08_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_08_z0.dat
# redshift  0.033023
# 53802.0
# SN2006aj_vlt_2006_03_09_z0.dat
# 37
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_09_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_09_z0.dat
# redshift  0.033023
# 53803.0
# SN2006aj_vlt_2006_03_10_z0.dat
# 38
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_10_z0.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/SN2006aj_vlt_2006_03_10_z0.dat
# redshift  0.033023
# 53804.0
# sn2006aj-20060921-mmt-b.flm
# 39
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060921-mmt-b.flm
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060921-mmt-b.flm
# redshift  0.033023
# 53999.0
# sn2006aj-20060921-mmt.flm
# 40
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060921-mmt.flm
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/sn2006aj-20060921-mmt.flm
# redshift  0.033023
# 53999.0
# 2006aj_20061127.ascii
# 41
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061127.ascii
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061127.ascii
# redshift  0.033023
# 54066.0
# 2006aj_20061127_3419_10599_00.dat
# 42
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061127_3419_10599_00.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061127_3419_10599_00.dat
# redshift  0.033023
# 54066
# 2006aj_20061219.ascii
# 43
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061219.ascii
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061219.ascii
# redshift  0.033023
# 54088.0
# 2006aj_20061219_3000_9631_00.dat
# 44
# /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061219_3000_9631_00.dat
# has data
# Writing /Users/berto/data/CoreCollapse/data/spectra/SN2006aj/2006aj_20061219_3000_9631_00.dat
# redshift  0.033023
# 54088

# %%
# out_array = np.append(combined, uncombined)

# %%
out_array = uncombined

# %%
out_array
# Out:
# array([ OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150215.256-ui.flm'), ('time', 57068.300000000003), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150225_TNG_LRS_cal.ascii'), ('time', 57078.0), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150225.171-ui.flm'), ('time', 57078.199999999997), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150227.34.deimos.flm'), ('time', 57080.300000000003), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150228_TNG_LRS_cal.ascii'), ('time', 57081.0), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150303_NOT_ALFOSC_cal.ascii'), ('time', 57084.0), ('redshift', 0.01379), ('snname', 'SN2015U')]),
#        OrderedDict([('filename', '/Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150311_NOT_ALFOSC_cal.ascii'), ('time', 57092.0), ('redshift', 0.01379), ('snname', 'SN2015U')])], dtype=object)

# %%
# [i["filename"] for i in out_array]
# [i["redshift"] for i in out_array]
# [i["snname"] for i in out_array]
# [i["time"] for i in out_array]

# %% [markdown]
# We need a (rough) estimate of the time of maximum light (only to ensure the spectra adhere to our naming convention), so from Folatelli et al. 2014 (http://iopscience.iop.org/article/10.1088/0004-637X/792/1/7/pdf) we have:

# %%
# mjdmax = 55286.4

# %%
# keys = out_array[0].keys()

keys = ["filename",
        "snname",
        "time",
        "redshift"]
columns = []
for key in keys:
    columns.append([i[key] for i in out_array])

# %%
keys[2] = "MJD"
list_table = Table(columns, names = keys)

# %%
list_table.add_index("MJD")
list_table.sort()

# %%
list_table
# Out:
# <Table length=21>
#                                                  filename                                                 ...
#                                                   str105                                                  ...
# --------------------------------------------------------------------------------------------------------- ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150215.256-ui.flm ...
#                  /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349.gal-20150215.256-ui.flm ...
# /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150217_Ekar182_AFOSC_cal.ascii ...
#              /Users/berto/data/CoreCollapse/data/spectra/SN2015U/SN2015U_2015-02-17_20:01:56_Asiago.ascii ...
# /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150218_Ekar182_AFOSC_cal.ascii ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150218.211-ir.flm ...
#                  /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349.gal-20150218.211-ir.flm ...
# /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150219_Ekar182_AFOSC_cal.ascii ...
#                  /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349.gal-20150221.207-ui.flm ...
#               /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349.sn+gal-20150221.207-ui.flm ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150221.207-ui.flm ...
#    /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150222_NOT_ALFOSC_cal.ascii ...
#       /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150223_TNG_LRS_cal.ascii ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150224.224-ui.flm ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150224.414-uh.flm ...
#       /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150225_TNG_LRS_cal.ascii ...
#                      /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150225.171-ui.flm ...
#                   /Users/berto/data/CoreCollapse/data/spectra/SN2015U/psn0728+3349-20150227.34.deimos.flm ...
#       /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150228_TNG_LRS_cal.ascii ...
#    /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150303_NOT_ALFOSC_cal.ascii ...
#    /Users/berto/data/CoreCollapse/data/spectra/SN2015U/PSNJ07285387p3349106_20150311_NOT_ALFOSC_cal.ascii ...

# %%
list_out_path = os.path.join(pcc.defaults._default_list_dir_path, snname+".list")
list_table.write(list_out_path, format="ascii.no_header")
# Out:
# WARNING: AstropyDeprecationWarning: /Users/berto/Code/CoCo/lists/SN2015U.list already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]

# %%
info = pcc.classes.InfoClass()
info.load()

# %%
info._data
# Out:
# <Table length=30>
#   snname   z_obs  ...     z_distmod                   SkyCoords
#                   ...                                  deg,deg
#    str9   float64 ...      float64                      object
# --------- ------- ... ----------------- --------------------------------------
#   SN1993J -0.0001 ... 0.000846738572565   148.85322791666664,69.02047277777778
#   SN1994I  0.0015 ...  0.00183405936245  202.47529999999995,47.191805555555554
#  SN1996cb  0.0024 ...  0.00316927429656  165.92491666666666,28.903805555555554
#  SN1998bw  0.0085 ...  0.00793139066351 293.76320833333324,-52.846138888888895
#  SN1999dn  0.0093 ...  0.00707356943452           354.06125,2.1524444444444444
#  SN2002ap  0.0022 ...  0.00206697015014           24.099375,15.753666666666666
#  SN2003jd  0.0188 ...     0.01676453466  350.2640833333333,-4.8959722222222215
#  SN2004aw  0.0159 ...   0.0179472672379  179.45933333333332,25.265305555555557
#  SN2005bf  0.0189 ...   0.0201040285508   155.9874583333333,-3.191472222222222
sndict.keys()
# Out:
# dict_keys(['schema', 'name', 'sources', 'alias', 'claimedtype', 'comovingdist', 'dec', 'discoverdate', 'discoverer', 'ebv', 'host', 'hostdec', 'hostoffsetang', 'hostoffsetdist', 'hostra', 'hostvelocity', 'lumdist', 'maxabsmag', 'maxappmag', 'maxband', 'maxdate', 'maxvisualabsmag', 'maxvisualappmag', 'maxvisualband', 'maxvisualdate', 'ra', 'redshift', 'velocity', 'photometry', 'spectra'])

# %%
sndict["lumdist"]
# Out:
# [{'derived': True,
#   'source': '2,4,9,10,12,14,16',
#   'u_value': 'Mpc',
#   'value': '61.673'}]

# %%
from astropy.cosmology import LambdaCDM
from astropy.coordinates import Distance

mu = 32.16 ## from NED -- https://ned.ipac.caltech.edu/ui/?q=objsearch&omegav=0.73&obj_sort=RA%20or%20Longitude&omegam=0.27&extend=no&hconst=73&out_csys=Equatorial&of=pre_text&img_stamp=YES&list_limit=5&out_equinox=J2000.0&corr_z=1&objname=NGC%206000

d = Distance(distmod=mu)

z_distmod = d.z

# %%
(snname, sndict["redshift"][0]["value"], mu, sndict["ra"][0]["value"], sndict["dec"][0]["value"], sndict["claimedtype"][0]["value"].replace("/", ""), z_distmod)
# Out:
# ('SN2015U',
#  '0.01379',
#  32.16,
#  '07:28:53.87',
#  '+33:49:10.6',
#  'Ibn',
#  0.0062219449351045312)

# %%
small_table.add_row((snname, sndict["redshift"][0]["value"], mu, sndict["ra"][0]["value"], sndict["dec"][0]["value"], sndict["claimedtype"][0]["value"].replace("/", ""), z_distmod))

# %%
small_table
# Out:
# <Table length=31>
#   snname   z_obs     mu         RA           Dec      Type     z_distmod
#    str9   float64 float64     str13         str13     str3      float64
# --------- ------- ------- ------------- ------------- ---- -----------------
#   SN1993J -0.0001   27.82 09:55:24.7747 +69:01:13.702  IIb 0.000846738572565
#   SN1994I  0.0015    29.5  13:29:54.072  +47:11:30.50   Ic  0.00183405936245
#  SN1996cb  0.0024   30.69   11:03:41.98   +28:54:13.7  IIb  0.00316927429656
#  SN1998bw  0.0085   32.69   19:35:03.17   -52:50:46.1   Ic  0.00793139066351
#  SN1999dn  0.0093   32.44   23:36:14.70   +02:09:08.8   Ib  0.00707356943452
#  SN2002ap  0.0022   29.76   01:36:23.85   +15:45:13.2   Ic  0.00206697015014
#  SN2003jd  0.0188   34.33   23:21:03.38   -04:53:45.5   Ic     0.01676453466
#  SN2004aw  0.0159   34.48   11:57:50.24   +25:15:55.1   Ic   0.0179472672379
#  SN2005bf  0.0189   34.73   10:23:56.99   -03:11:29.3   Ib   0.0201040285508
#  SN2005hg   0.021   34.54   01:55:41.87   +46:47:47.4   Ib   0.0184430908334
#       ...     ...     ...           ...           ...  ...               ...
#  SN2009jf   0.008   32.58   23:04:52.98   +12:19:59.5   Ib  0.00754189788211
#  SN2010al   0.017   34.74   08:14:15.91   +18:26:18.2   Ib   0.0201954171702
#  SN2011bm  0.0022   35.53   12:56:53.89   +22:22:28.2   Ic   0.0288668876597
#  SN2011dh  0.0015    29.5 13:30:05.1055 +47:10:10.922  IIb  0.00183405936245
#  SN2011ei  0.0093   32.41   20:34:22.62   -31:58:23.6  IIb  0.00697703973932
#  SN2011fu  0.0185   34.46   02:08:21.41   +41:29:12.3  IIb   0.0177849337761
#  SN2012ap  0.0121   32.96   05:00:13.72   -03:20:51.2   Ib  0.00897424974731
#  SN2013ge  0.0043   31.36   10:34:48.46   +21:39:41.9   Ib  0.00431094726025
# iPTF13bvn 0.00449   32.14   15:00:00.15  +01:52:53.17   Ib  0.00616517411033
#   SN2015U 0.01379   32.16   07:28:53.87   +33:49:10.6  Ibn   0.0062219449351

# %%
outfile = pcc._default_info_path.replace(".dat", "_new.dat")
small_table.write(outfile, format="ascii.commented_header")
# Out:
# WARNING: AstropyDeprecationWarning: /Users/berto/Code/CoCo/data/info/info_new.dat already exists. Automatically overwriting ASCII files is deprecated. Use the argument 'overwrite=True' in the future. [astropy.io.ascii.ui]

# %% [markdown]
# # Photometry
# ---

# %%
sndict["photometry"]
# Out:
# [{'band': 'clear',
#   'e_magnitude': '0.1515',
#   'magnitude': '18.0616',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57064.24',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0646',
#   'magnitude': '16.8465',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57066.22',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1749',
#   'magnitude': '17.7117',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57067.35',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0592',
#   'magnitude': '16.4640',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57067.35',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0891',
#   'magnitude': '16.9832',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57067.35',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0542',
#   'magnitude': '16.5726',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57067.35',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0766',
#   'magnitude': '16.1834',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57067.36',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1072',
#   'magnitude': '17.6548',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57068.21',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0561',
#   'magnitude': '16.2318',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57068.22',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0277',
#   'magnitude': '16.4146',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57068.22',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0476',
#   'magnitude': '16.8599',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57068.22',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0874',
#   'magnitude': '17.6547',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57070.19',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0486',
#   'magnitude': '15.8808',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57070.19',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0456',
#   'magnitude': '16.1528',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57070.19',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0448',
#   'magnitude': '16.7444',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57070.19',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0306',
#   'magnitude': '16.2282',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57070.22',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.06',
#   'magnitude': '17.71',
#   'source': '3,11',
#   'time': '57070.72',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.04',
#   'magnitude': '15.74',
#   'source': '3,11',
#   'time': '57070.72',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.04',
#   'magnitude': '16.19',
#   'source': '3,11',
#   'time': '57070.72',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.04',
#   'magnitude': '16.72',
#   'source': '3,11',
#   'time': '57070.72',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0779',
#   'magnitude': '17.6867',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57071.21',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0373',
#   'magnitude': '15.7717',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57071.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0313',
#   'magnitude': '16.2086',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57071.21',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0366',
#   'magnitude': '16.6743',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57071.21',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0269',
#   'magnitude': '16.1795',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57071.21',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.04',
#   'magnitude': '17.61',
#   'source': '3,11',
#   'time': '57071.81',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.05',
#   'magnitude': '15.91',
#   'source': '3,11',
#   'time': '57071.81',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.04',
#   'magnitude': '16.12',
#   'source': '3,11',
#   'time': '57071.81',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.04',
#   'magnitude': '16.64',
#   'source': '3,11',
#   'time': '57071.81',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0918',
#   'magnitude': '17.6771',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57072.23',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0406',
#   'magnitude': '15.8651',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57072.23',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0278',
#   'magnitude': '16.2732',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57072.23',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0448',
#   'magnitude': '16.7492',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57072.23',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0302',
#   'magnitude': '16.2832',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57072.24',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0290',
#   'magnitude': '16.2939',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57073.24',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0391',
#   'magnitude': '16.8228',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57073.24',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0159',
#   'magnitude': '16.2797',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57073.24',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1321',
#   'magnitude': '17.9040',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57073.25',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0368',
#   'magnitude': '15.8771',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57073.25',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.05',
#   'magnitude': '17.66',
#   'source': '3,11',
#   'time': '57073.81',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.04',
#   'magnitude': '15.92',
#   'source': '3,11',
#   'time': '57073.81',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.04',
#   'magnitude': '16.16',
#   'source': '3,11',
#   'time': '57073.81',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.03',
#   'magnitude': '16.76',
#   'source': '3,11',
#   'time': '57073.81',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1024',
#   'magnitude': '17.8597',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57074.18',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0393',
#   'magnitude': '15.8593',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57074.18',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0377',
#   'magnitude': '16.2889',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57074.18',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0470',
#   'magnitude': '16.8533',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57074.18',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0224',
#   'magnitude': '16.3543',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57074.19',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0947',
#   'magnitude': '17.9449',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57075.20',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0368',
#   'magnitude': '15.9706',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57075.20',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0330',
#   'magnitude': '16.4309',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57075.20',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0403',
#   'magnitude': '17.0206',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57075.20',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0230',
#   'magnitude': '16.4839',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57075.20',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0168',
#   'magnitude': '18.0282',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57075.31',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0075',
#   'magnitude': '15.9683',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57075.32',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0061',
#   'magnitude': '16.4421',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57075.32',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0086',
#   'magnitude': '17.0530',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57075.32',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.04',
#   'magnitude': '17.82',
#   'source': '3,11',
#   'time': '57075.89',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.04',
#   'magnitude': '15.94',
#   'source': '3,11',
#   'time': '57075.89',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.03',
#   'magnitude': '16.4',
#   'source': '3,11',
#   'time': '57075.89',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.04',
#   'magnitude': '16.86',
#   'source': '3,11',
#   'time': '57075.89',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1285',
#   'magnitude': '18.0733',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57076.20',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0448',
#   'magnitude': '16.0555',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57076.20',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0350',
#   'magnitude': '16.4603',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57076.20',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0529',
#   'magnitude': '17.0246',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57076.20',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0304',
#   'magnitude': '16.4759',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57076.21',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1441',
#   'magnitude': '18.1106',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57077.19',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0480',
#   'magnitude': '16.1347',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57077.19',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0388',
#   'magnitude': '16.5394',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57077.19',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0529',
#   'magnitude': '17.1759',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57077.19',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0243',
#   'magnitude': '16.6425',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57077.19',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.05',
#   'magnitude': '18.17',
#   'source': '3,11',
#   'time': '57077.78',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.04',
#   'magnitude': '16.15',
#   'source': '3,11',
#   'time': '57077.78',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.04',
#   'magnitude': '16.55',
#   'source': '3,11',
#   'time': '57077.78',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.03',
#   'magnitude': '17.24',
#   'source': '3,11',
#   'time': '57077.78',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0312',
#   'magnitude': '16.6341',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57078.17',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1530',
#   'magnitude': '18.2235',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57078.19',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0419',
#   'magnitude': '16.6174',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57078.19',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0566',
#   'magnitude': '17.2449',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57078.19',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0417',
#   'magnitude': '16.1638',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57078.20',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.09',
#   'magnitude': '16.55',
#   'source': '3,11',
#   'time': '57078.65',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.2433',
#   'magnitude': '18.4493',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57079.21',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0550',
#   'magnitude': '16.2618',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57079.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0464',
#   'magnitude': '16.7881',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57079.21',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0828',
#   'magnitude': '17.3975',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57079.21',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0333',
#   'magnitude': '16.7395',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57079.21',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.0379',
#   'magnitude': '18.5111',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57079.30',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0119',
#   'magnitude': '16.7911',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57079.30',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0176',
#   'magnitude': '17.4653',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57079.30',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0221',
#   'magnitude': '16.2658',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57079.31',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.11',
#   'magnitude': '18.65',
#   'source': '3,11',
#   'time': '57079.66',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.06',
#   'magnitude': '16.36',
#   'source': '3,11',
#   'time': '57079.66',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.05',
#   'magnitude': '16.81',
#   'source': '3,11',
#   'time': '57079.66',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.09',
#   'magnitude': '17.37',
#   'source': '3,11',
#   'time': '57079.66',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.2330',
#   'magnitude': '18.5313',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57080.21',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0557',
#   'magnitude': '16.4097',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57080.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0521',
#   'magnitude': '16.8854',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57080.21',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0691',
#   'magnitude': '17.4432',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57080.21',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0379',
#   'magnitude': '16.9051',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57080.22',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.1552',
#   'magnitude': '17.0336',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57084.23',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.1262',
#   'magnitude': '17.4188',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57084.23',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.2656',
#   'magnitude': '17.9939',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57084.23',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.1044',
#   'magnitude': '17.2140',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57084.25',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'e_magnitude': '0.1087',
#   'magnitude': '18.9517',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57084.35',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.0502',
#   'magnitude': '18.1519',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57084.35',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0193',
#   'magnitude': '16.7364',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57084.36',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0283',
#   'magnitude': '17.4395',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57084.36',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.1346',
#   'magnitude': '17.2390',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57085.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.1164',
#   'magnitude': '17.6252',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57085.21',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.1529',
#   'magnitude': '18.0094',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57085.21',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0760',
#   'magnitude': '17.5569',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57085.24',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.1557',
#   'magnitude': '17.8391',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57086.18',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.2191',
#   'magnitude': '18.1469',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57086.19',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.0918',
#   'magnitude': '17.8184',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57086.21',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.1331',
#   'magnitude': '17.6989',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57087.20',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.1681',
#   'magnitude': '18.1496',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57087.20',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.1939',
#   'magnitude': '18.7344',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57087.20',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.1291',
#   'magnitude': '17.8062',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57087.25',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.3254',
#   'magnitude': '18.1446',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57088.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.1802',
#   'magnitude': '18.2639',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57088.21',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.2386',
#   'magnitude': '18.6242',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57088.21',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.2174',
#   'magnitude': '18.6191',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57089.18',
#   'u_time': 'MJD'},
#  {'band': 'clear',
#   'e_magnitude': '0.1662',
#   'magnitude': '18.3348',
#   'source': '1,13',
#   'telescope': 'KAIT',
#   'time': '57089.20',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.0563',
#   'magnitude': '18.7836',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57089.28',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.1284',
#   'magnitude': '19.7519',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57089.28',
#   'u_time': 'MJD'},
#  {'band': 'I',
#   'e_magnitude': '0.0664',
#   'magnitude': '17.9578',
#   'source': '1,13',
#   'telescope': 'Nick',
#   'time': '57089.29',
#   'u_time': 'MJD'},
#  {'band': 'R',
#   'e_magnitude': '0.12',
#   'magnitude': '19.8',
#   'source': '3,11',
#   'time': '57091.72',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'e_magnitude': '0.21',
#   'magnitude': '20.23',
#   'source': '3,11',
#   'time': '57091.72',
#   'u_time': 'MJD'}]

# %%
phot_dict_list = sndict["photometry"]
new_phot_dict_list = []
for i in phot_dict_list:
    out_dict = OrderedDict()
    
    out_dict["MJD"] = i["time"]
    out_dict["mag"] = i["magnitude"]
    out_dict["dmag"] = i["e_magnitude"]
    out_dict["filter"] = i["band"]
    
    new_phot_dict_list.append(out_dict)

# %%
phot_table=Table(rows=new_phot_dict_list)

# %%
phot_table
# Out:
# <Table length=128>
#   MJD     dmag  filter   mag
#   str8    str6   str5    str7
# -------- ------ ------ -------
# 57064.24 0.1515  clear 18.0616
# 57066.22 0.0646  clear 16.8465
# 57067.35 0.1749      B 17.7117
# 57067.35 0.0592      R 16.4640
# 57067.35 0.0891      V 16.9832
# 57067.35 0.0542  clear 16.5726
# 57067.36 0.0766      I 16.1834
# 57068.21 0.1072      B 17.6548
# 57068.22 0.0561      I 16.2318
# 57068.22 0.0277      R 16.4146
#      ...    ...    ...     ...
# 57088.21 0.3254      I 18.1446
# 57088.21 0.1802      R 18.2639
# 57088.21 0.2386      V 18.6242
# 57089.18 0.2174      R 18.6191
# 57089.20 0.1662  clear 18.3348
# 57089.28 0.0563      R 18.7836
# 57089.28 0.1284      V 19.7519
# 57089.29 0.0664      I 17.9578
# 57091.72   0.12      R    19.8
# 57091.72   0.21      V   20.23

# %%
w = np.where(phot_table["filter"] != "clear")
# print(w)

# %%
phot_table_filtered = phot_table[w]

# %%
# pcc.calc_AB_zp?
filt_dict = OrderedDict()

for filter_name in np.unique(phot_table_filtered["filter"]):
#     filter_name = "Bessell"+filter_name
#     filter_dir_path = os.path.join(pcc.defaults._default_filter_dir_path, "Bessell"+filter_name+".dat")
    print(filter_name)
    filter_object = pcc.classes.FilterClass()
    filter_object.load(path=os.path.join(pcc.defaults._default_filter_dir_path, "Bessell"+filter_name+".dat"), fmt="ascii",
                      name="Bessell"+filter_name)
    filter_object.calculate_AB_zp()
    filt_dict["Bessell"+filter_name]=filter_object
# Out:
# B
# I
# R
# V

# %%
phot_table_filtered["filter"] = Column(list(map(lambda x: "Bessell"+x, phot_table_filtered["filter"])))

# %%
phot_table_filtered
# Out:
# <Table length=109>
#   MJD     dmag   filter    mag
#   str8    str6    str8     str7
# -------- ------ -------- -------
# 57067.35 0.1749 BessellB 17.7117
# 57067.35 0.0592 BessellR 16.4640
# 57067.35 0.0891 BessellV 16.9832
# 57067.36 0.0766 BessellI 16.1834
# 57068.21 0.1072 BessellB 17.6548
# 57068.22 0.0561 BessellI 16.2318
# 57068.22 0.0277 BessellR 16.4146
# 57068.22 0.0476 BessellV 16.8599
# 57070.19 0.0874 BessellB 17.6547
# 57070.19 0.0486 BessellI 15.8808
#      ...    ...      ...     ...
# 57087.20 0.1939 BessellV 18.7344
# 57088.21 0.3254 BessellI 18.1446
# 57088.21 0.1802 BessellR 18.2639
# 57088.21 0.2386 BessellV 18.6242
# 57089.18 0.2174 BessellR 18.6191
# 57089.28 0.0563 BessellR 18.7836
# 57089.28 0.1284 BessellV 19.7519
# 57089.29 0.0664 BessellI 17.9578
# 57091.72   0.12 BessellR    19.8
# 57091.72   0.21 BessellV   20.23

# %%
# filt_dict["BessellB"].zp_AB
phot_table_filtered["zp_AB"] = Column(list(map(lambda x: filt_dict[x].zp_AB, phot_table_filtered["filter"])), name="zp_AB")

# %%
phot_table_filtered["zp_AB"] phot_table_filtered["mag"]
# Out:
# <Table length=109>
#   MJD     dmag   filter    mag       zp_AB
#   str8    str6    str8     str7     float64
# -------- ------ -------- ------- -------------
# 57067.35 0.1749 BessellB 17.7117 20.6105923281
# 57067.35 0.0592 BessellR 16.4640  21.473516209
# 57067.35 0.0891 BessellV 16.9832 21.1007662906
# 57067.36 0.0766 BessellI 16.1834 21.9288297472
# 57068.21 0.1072 BessellB 17.6548 20.6105923281
# 57068.22 0.0561 BessellI 16.2318 21.9288297472
# 57068.22 0.0277 BessellR 16.4146  21.473516209
# 57068.22 0.0476 BessellV 16.8599 21.1007662906
# 57070.19 0.0874 BessellB 17.6547 20.6105923281
# 57070.19 0.0486 BessellI 15.8808 21.9288297472
#      ...    ...      ...     ...           ...
# 57087.20 0.1939 BessellV 18.7344 21.1007662906
# 57088.21 0.3254 BessellI 18.1446 21.9288297472
# 57088.21 0.1802 BessellR 18.2639  21.473516209
# 57088.21 0.2386 BessellV 18.6242 21.1007662906
# 57089.18 0.2174 BessellR 18.6191  21.473516209
# 57089.28 0.0563 BessellR 18.7836  21.473516209
# 57089.28 0.1284 BessellV 19.7519 21.1007662906
# 57089.29 0.0664 BessellI 17.9578 21.9288297472
# 57091.72   0.12 BessellR    19.8  21.473516209
# 57091.72   0.21 BessellV   20.23 21.1007662906

# %%
SN = pcc.classes.SNClass(snname)
SN.load_phot()
SN.plot_lc()

# %%
list_file_path = "/Users/berto/Code/CoCo/lists/"+snname+".list"
# list_file_path = "/Users/berto/data/CoreCollapse/SNe/SN2010as.list"
SN.load_list(path=list_file_path)

# %%
SN.load_spec()

# %%
SN.plot_spec()

# %%
SN.spec

# %%
fit_path = "/Users/berto/Code/CoCo/recon/"+snname+".dat"
SN.get_lcfit(fit_path)

SN.plot_lc()

# %%
# pcc.run_specfit(list_file_path)
