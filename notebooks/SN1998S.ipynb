# %%
# %matplotlib notebook
import os
import numpy as np
import matplotlib.pyplot as plt

import astropy as ap
import pycoco as pcc

# %%
path = "/Users/berto/data/SN1998S.json"

# %%
import json

# %%
data = json.load(open(path, 'r'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-06b6b85c5fa4> in <module>()
# ----> 1 data = json.load(open(path, 'r'))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/berto/data/SN1998S.json'

# %%
data["SN1998S"]

# %%
data["SN1998S"]["photometry"]
# Out:
# [{'band': 'C',
#   'magnitude': '16',
#   'source': '14,18',
#   'time': '50874.7',
#   'u_time': 'MJD'},
#  {'band': 'C',
#   'magnitude': '13.22',
#   'source': '14,18',
#   'time': '50877.62',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'magnitude': '13.48',
#   'source': '14,18',
#   'time': '50877.79',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'magnitude': '13.39',
#   'source': '14,18',
#   'time': '50877.79',
#   'u_time': 'MJD'},
#  {'band': 'C',
#   'magnitude': '13.1',
#   'source': '14,18',
#   'time': '50877.88',
#   'u_time': 'MJD'},
#  {'band': 'V',
#   'magnitude': '13.17',
#   'source': '14,18',
#   'time': '50878.61',
#   'u_time': 'MJD'},
#  {'band': 'C',
#   'magnitude': '12.9',
#   'source': '14,18',
#   'time': '50878.62',
#   'u_time': 'MJD'},
#  {'band': 'C',
#   'magnitude': '13',
#   'source': '14,18',
#   'time': '50878.63',
#   'u_time': 'MJD'},
#  {'band': 'B',
#   'magnitude': '13.25',
#   'source': '14,18',
#   'time': '50878.66',
#   'u_time': 'MJD'},
# ...
